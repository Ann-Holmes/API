# %% [markdown]
# # Mediawiki
#
# ## search.py

# %%
import requests

S = requests.Session()

URL = "https://en.wikipedia.org/w/api.php"

SEARCHPAGE = "Nelson Mandela"

PARAMS = {
    'action':"query",
    'list':"search",
    'srsearch': SEARCHPAGE,
    'format':"json"
}

R = S.get(url=URL, params=PARAMS)
DATA = R.json()

if DATA['query']['search'][0]['title'] == SEARCHPAGE:
    print("Your search page '" + SEARCHPAGE + "' exists on English Wikipedia")
# Out:
# Your search page 'Nelson Mandela' exists on English Wikipedia

# %%
import pprint
pprint.pprint(DATA)
# Out:
# {'batchcomplete': '',
#  'continue': {'continue': '-||', 'sroffset': 10},
#  'query': {'search': [{'ns': 0,
#                        'pageid': 21492751,
#                        'size': 196774,
#                        'snippet': '<span class="searchmatch">Nelson</span> '
#                                   'Rolihlahla <span '
#                                   'class="searchmatch">Mandela</span> '
#                                   '(/mænˈdɛlə/; Xhosa:\xa0[xolíɬaɬa <span '
#                                   'class="searchmatch">mandɛ̂ːla</span>]; 18 '
#                                   'July 1918\xa0– 5 December 2013) was a South '
#                                   'African anti-apartheid revolutionary,',
#                        'timestamp': '2019-01-28T12:37:16Z',
#                        'title': 'Nelson Mandela',
#                        'wordcount': 23738},
#                       {'ns': 0,
#                        'pageid': 41284488,
#                        'size': 132412,
#                        'snippet': 'On 5 December 2013, <span '
#                                   'class="searchmatch">Nelson</span> <span '
#                                   'class="searchmatch">Mandela</span>, the '
#                                   'first President of South Africa to be '
#                                   'elected in a fully representative '
#                                   'democratic election, as well as the '
#                                   "country's",
#                        'timestamp': '2019-01-29T11:30:23Z',
#                        'title': 'Death of Nelson Mandela',
#                        'wordcount': 13495},
#                       {'ns': 0,
#                        'pageid': 4761992,
#                        'size': 44294,
#                        'snippet': 'The <span class="searchmatch">Nelson</span> '
#                                   '<span class="searchmatch">Mandela</span> '
#                                   'Bay Stadium is a 46,000-seater stadium in '
#                                   'Port Elizabeth, Eastern Cape, South Africa. '
#                                   'The five-tier, R2 billion (approximately '
#                                   '$159',
#                        'timestamp': '2019-01-18T12:18:26Z',
#                        'title': 'Nelson Mandela Bay Stadium',
#                        'wordcount': 4565},
#                       {'ns': 0,
#                        'pageid': 881536,
#                        'size': 39070,
#                        'snippet': '<span class="searchmatch">Nelson</span> '
#                                   '<span class="searchmatch">Mandela</span> '
#                                   'University, formerly known as University of '
#                                   'Port Elizabeth (UPE), is a South African '
#                                   'university with its main administration in '
#                                   'the coastal',
#                        'timestamp': '2019-01-24T14:42:08Z',
#                        'title': 'Nelson Mandela University',
#                        'wordcount': 4541},
#                       {'ns': 0,
#                        'pageid': 1720632,
#                        'size': 14778,
#                        'snippet': 'Infobox settlement is being considered for '
#                                   'merging.\xa0› <span '
#                                   'class="searchmatch">Nelson</span> <span '
#                                   'class="searchmatch">Mandela</span> Bay '
#                                   'Municipality (Afrikaans: <span '
#                                   'class="searchmatch">Nelson</span> '
#                                   'Mandelabaai Metropolitaanse Munisipaliteit) '
#                                   'is one',
#                        'timestamp': '2018-10-01T07:39:06Z',
#                        'title': 'Nelson Mandela Bay Metropolitan Municipality',
#                        'wordcount': 873},
#                       {'ns': 0,
#                        'pageid': 32300871,
#                        'size': 10950,
#                        'snippet': 'The presidency of <span '
#                                   'class="searchmatch">Nelson</span> <span '
#                                   'class="searchmatch">Mandela</span> began on '
#                                   '10 May 1994, when <span '
#                                   'class="searchmatch">Nelson</span> <span '
#                                   'class="searchmatch">Mandela</span>, an '
#                                   'anti-apartheid activist, lawyer, and former '
#                                   'political prisoner, was inaugurated',
#                        'timestamp': '2018-12-17T16:48:13Z',
#                        'title': 'Presidency of Nelson Mandela',
#                        'wordcount': 1107},
#                       {'ns': 0,
#                        'pageid': 7585993,
#                        'size': 9368,
#                        'snippet': '&quot;<span '
#                                   'class="searchmatch">Nelson</span> <span '
#                                   'class="searchmatch">Mandela</span>&quot; '
#                                   '(known in some versions as &quot;Free <span '
#                                   'class="searchmatch">Nelson</span> <span '
#                                   'class="searchmatch">Mandela</span>&quot;) '
#                                   'is a song written by British musician Jerry '
#                                   'Dammers, and performed by band The Special',
#                        'timestamp': '2018-11-21T22:47:58Z',
#                        'title': 'Free Nelson Mandela',
#                        'wordcount': 883},
#                       {'ns': 0,
#                        'pageid': 2360500,
#                        'size': 35452,
#                        'snippet': 'The <span class="searchmatch">Nelson</span> '
#                                   '<span class="searchmatch">Mandela</span> '
#                                   '70th Birthday Tribute was a popular-music '
#                                   'concert staged on 11 June 1988 at Wembley '
#                                   'Stadium, London, and broadcast to 67 '
#                                   'countries and',
#                        'timestamp': '2019-01-27T14:17:47Z',
#                        'title': 'Nelson Mandela 70th Birthday Tribute',
#                        'wordcount': 5076},
#                       {'ns': 0,
#                        'pageid': 33683,
#                        'size': 68864,
#                        'snippet': 'African anti-apartheid activist and '
#                                   'politician, and the ex-wife of <span '
#                                   'class="searchmatch">Nelson</span> <span '
#                                   'class="searchmatch">Mandela</span>. She '
#                                   'served as a Member of Parliament from 1994 '
#                                   'to 2003, and from 2009',
#                        'timestamp': '2019-01-21T06:25:19Z',
#                        'title': 'Winnie Madikizela-Mandela',
#                        'wordcount': 6180},
#                       {'ns': 0,
#                        'pageid': 3373964,
#                        'size': 6725,
#                        'snippet': '<span class="searchmatch">Nelson</span> '
#                                   '<span class="searchmatch">Mandela</span> '
#                                   'International Airport (IATA: RAI, ICAO: '
#                                   'GVNP), also known as Praia International '
#                                   'Airport, is the airport of Santiago Island '
#                                   'in Cape Verde',
#                        'timestamp': '2018-12-07T19:50:42Z',
#                        'title': 'Nelson Mandela International Airport',
#                        'wordcount': 369}],
#            'searchinfo': {'totalhits': 5257}}}

# %% [markdown]
# ## opensearch

# %%
import requests
import pprint

S = requests.Session()

URL = "https://en.wikipedia.org/w/api.php"

SEARCHTERM = "DNA"

PARAMS = {
    'action':"opensearch",
    'search':SEARCHTERM,
    'limit': 5,
    'namespace':0,
    'format':"json"
}

R = S.get(url=URL, params=PARAMS)
DATA = R.json()

pprint.pprint(DATA)
# Out:
# ['DNA',
#  ['DNA',
#   'DNA profiling',
#   'DNA sequencing',
#   'DNA replication',
#   'DNA polymerase'],
#  ['Deoxyribonucleic acid ( (listen); DNA) is a molecule composed of two chains '
#   'that coil around each other to form a double helix carrying the genetic '
#   'instructions used in the growth, development, functioning, and reproduction '
#   'of all known living organisms and many viruses.',
#   'DNA profiling (also called DNA fingerprinting) is the process of '
#   "determining an individual's DNA characteristics, which are as unique as "
#   'fingerprints.',
#   'DNA sequencing is the process of determining the nucleic acid sequence – '
#   'the order of nucleotides in DNA.',
#   'In molecular biology, DNA replication is the biological process of '
#   'producing two identical replicas of DNA from one original DNA molecule and '
#   'occurs in all living organisms acting as the basis for biological '
#   'inheritance.',
#   'DNA polymerase is an enzyme that synthesizes DNA molecules from '
#   'deoxyribonucleotides, the building blocks of DNA.'],
#  ['https://en.wikipedia.org/wiki/DNA',
#   'https://en.wikipedia.org/wiki/DNA_profiling',
#   'https://en.wikipedia.org/wiki/DNA_sequencing',
#   'https://en.wikipedia.org/wiki/DNA_replication',
#   'https://en.wikipedia.org/wiki/DNA_polymerase']]
